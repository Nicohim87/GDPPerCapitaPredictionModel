# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("global-data-on-sustainable-energy.csv")
data
# Out:
#            Entity  Year  Access to electricity (% of population)  \
# 0     Afghanistan  2000                                 1.613591
# 1     Afghanistan  2001                                 4.074574
# 2     Afghanistan  2002                                 9.409158
# 3     Afghanistan  2003                                14.738506
# 4     Afghanistan  2004                                20.064968
# ...           ...   ...                                      ...
# 3644     Zimbabwe  2016                                42.561730
# 3645     Zimbabwe  2017                                44.178635
# 3646     Zimbabwe  2018                                45.572647
# 3647     Zimbabwe  2019                                46.781475
# 3648     Zimbabwe  2020                                52.747670
#
#       Access to clean fuels for cooking  \
# 0                                   6.2
# 1                                   7.2
# 2                                   8.2
# 3                                   9.5
# 4                                  10.9
# ...                                 ...
# 3644                               29.8
# 3645                               29.8
# 3646                               29.9
# 3647                               30.1
# 3648                               30.4
#
#       Renewable-electricity-generating-capacity-per-capita  \
# 0                                                  9.22
# 1                                                  8.86
# 2                                                  8.47
# 3                                                  8.09
# 4                                                  7.75
# ...                                                 ...
# 3644                                              62.88
# 3645                                              62.33
# 3646                                              82.53
# 3647                                              81.40
# 3648                                              80.61
#
#       Financial flows to developing countries (US $)  \
# 0                                            20000.0
# 1                                           130000.0
# 2                                          3950000.0
# 3                                         25970000.0
# 4                                                NaN
# ...                                              ...
# 3644                                         30000.0
# 3645                                       5570000.0
# 3646                                         10000.0
# 3647                                        250000.0
# 3648                                         30000.0
#
#       Renewable energy share in the total final energy consumption (%)  \
# 0                                                 44.99
# 1                                                 45.60
# 2                                                 37.83
# 3                                                 36.66
# 4                                                 44.24
# ...                                                 ...
# 3644                                              81.90
# 3645                                              82.46
# 3646                                              80.23
# 3647                                              81.50
# 3648                                              81.90
#
#       Electricity from fossil fuels (TWh)  Electricity from nuclear (TWh)  \
# 0                                    0.16                             0.0
# 1                                    0.09                             0.0
# 2                                    0.13                             0.0
# 3                                    0.31                             0.0
# 4                                    0.33                             0.0
# ...                                   ...                             ...
# 3644                                 3.50                             0.0
# 3645                                 3.05                             0.0
# 3646                                 3.73                             0.0
# 3647                                 3.66                             0.0
# 3648                                 3.40                             0.0
#
#       Electricity from renewables (TWh)  ...  \
# 0                                  0.31  ...
# 1                                  0.50  ...
# 2                                  0.56  ...
# 3                                  0.63  ...
# 4                                  0.56  ...
# ...                                 ...  ...
# 3644                               3.32  ...
# 3645                               4.30  ...
# 3646                               5.46  ...
# 3647                               4.58  ...
# 3648                               4.19  ...
#
#       Primary energy consumption per capita (kWh/person)  \
# 0                                             302.59482
# 1                                             236.89185
# 2                                             210.86215
# 3                                             229.96822
# 4                                             204.23125
# ...                                                 ...
# 3644                                         3227.68020
# 3645                                         3068.01150
# 3646                                         3441.98580
# 3647                                         3003.65530
# 3648                                         2680.13180
#
#       Energy intensity level of primary energy (MJ/$2017 PPP GDP)  \
# 0                                                  1.64
# 1                                                  1.74
# 2                                                  1.40
# 3                                                  1.40
# 4                                                  1.20
# ...                                                 ...
# 3644                                              10.00
# 3645                                               9.51
# 3646                                               9.83
# 3647                                              10.47
# 3648                                              10.00
#
#       Value_co2_emissions_kt_by_country  \
# 0                            760.000000
# 1                            730.000000
# 2                           1029.999971
# 3                           1220.000029
# 4                           1029.999971
# ...                                 ...
# 3644                       11020.000460
# 3645                       10340.000150
# 3646                       12380.000110
# 3647                       11760.000230
# 3648                                NaN
#
#       Renewables (% equivalent primary energy)  gdp_growth  gdp_per_capita  \
# 0                                          NaN         NaN             NaN
# 1                                          NaN         NaN             NaN
# 2                                          NaN         NaN      179.426579
# 3                                          NaN    8.832278      190.683814
# 4                                          NaN    1.414118      211.382074
# ...                                        ...         ...             ...
# 3644                                       NaN    0.755869     1464.588957
# 3645                                       NaN    4.709492     1235.189032
# 3646                                       NaN    4.824211     1254.642265
# 3647                                       NaN   -6.144236     1316.740657
# 3648                                       NaN   -6.248748     1214.509820
#
#       Density\n(P/Km2) Land Area(Km2)   Latitude  Longitude
# 0                   60       652230.0  33.939110  67.709953
# 1                   60       652230.0  33.939110  67.709953
# 2                   60       652230.0  33.939110  67.709953
# 3                   60       652230.0  33.939110  67.709953
# 4                   60       652230.0  33.939110  67.709953
# ...                ...            ...        ...        ...
# 3644                38       390757.0 -19.015438  29.154857
# 3645                38       390757.0 -19.015438  29.154857
# 3646                38       390757.0 -19.015438  29.154857
# 3647                38       390757.0 -19.015438  29.154857
# 3648                38       390757.0 -19.015438  29.154857
#
# [3649 rows x 21 columns]

# %%
data.isnull().sum()
# Out:
# Entity                                                                 0
# Year                                                                   0
# Access to electricity (% of population)                               10
# Access to clean fuels for cooking                                    169
# Renewable-electricity-generating-capacity-per-capita                 931
# Financial flows to developing countries (US $)                      2089
# Renewable energy share in the total final energy consumption (%)     194
# Electricity from fossil fuels (TWh)                                   21
# Electricity from nuclear (TWh)                                       126
# Electricity from renewables (TWh)                                     21
# Low-carbon electricity (% electricity)                                42
# Primary energy consumption per capita (kWh/person)                     0
# Energy intensity level of primary energy (MJ/$2017 PPP GDP)          207
# Value_co2_emissions_kt_by_country                                    428
# Renewables (% equivalent primary energy)                            2137
# gdp_growth                                                           317
# gdp_per_capita                                                       282
# Density\n(P/Km2)                                                       1
# Land Area(Km2)                                                         1
# Latitude                                                               1
# Longitude                                                              1
# dtype: int64

# %%
a = np.zeros(21, dtype="int") 
y = np.zeros(21, dtype="int")


for i in range(21):
    a[i] = len(data[data["Year"] == 2000+i])
    y[i] = 2000+i

Country_Amount = pd.DataFrame({"Year":y, "Amount":a})

Country_Amount
# Out:
#     Year  Amount
# 0   2000     173
# 1   2001     172
# 2   2002     172
# 3   2003     172
# 4   2004     172
# 5   2005     172
# 6   2006     172
# 7   2007     174
# 8   2008     174
# 9   2009     174
# 10  2010     174
# 11  2011     174
# 12  2012     174
# 13  2013     175
# 14  2014     175
# 15  2015     175
# 16  2016     175
# 17  2017     175
# 18  2018     175
# 19  2019     175
# 20  2020     175

# %%
data["Entity"].value_counts()
# Out:
# Entity
# Afghanistan      21
# Oman             21
# Netherlands      21
# New Caledonia    21
# New Zealand      21
#                  ..
# Zimbabwe         21
# Serbia           14
# Montenegro       14
# South Sudan       8
# French Guiana     1
# Name: count, Length: 176, dtype: int64

# %%
entity_counts = data["Entity"].value_counts()

eligible_entities = entity_counts[entity_counts == 21].index
Eligible = data[data["Entity"].isin(eligible_entities)]

ineligible_entities = entity_counts[entity_counts != 21].index
Ineligible = data[data["Entity"].isin(ineligible_entities)]

# %%
Ineligible["Entity"].value_counts()
# Out:
# Entity
# Montenegro       14
# Serbia           14
# South Sudan       8
# French Guiana     1
# Name: count, dtype: int64

# %%
Eligible["Entity"].value_counts().sort_index()
# Out:
# Entity
# Afghanistan            21
# Albania                21
# Algeria                21
# Angola                 21
# Antigua and Barbuda    21
#                        ..
# Uzbekistan             21
# Vanuatu                21
# Yemen                  21
# Zambia                 21
# Zimbabwe               21
# Name: count, Length: 172, dtype: int64

# %%
Eligible.isnull().sum()
# Out:
# Entity                                                                 0
# Year                                                                   0
# Access to electricity (% of population)                                9
# Access to clean fuels for cooking                                    168
# Renewable-electricity-generating-capacity-per-capita                 903
# Financial flows to developing countries (US $)                      2058
# Renewable energy share in the total final energy consumption (%)     191
# Electricity from fossil fuels (TWh)                                   21
# Electricity from nuclear (TWh)                                       126
# Electricity from renewables (TWh)                                     21
# Low-carbon electricity (% electricity)                                42
# Primary energy consumption per capita (kWh/person)                     0
# Energy intensity level of primary energy (MJ/$2017 PPP GDP)          199
# Value_co2_emissions_kt_by_country                                    424
# Renewables (% equivalent primary energy)                            2100
# gdp_growth                                                           311
# gdp_per_capita                                                       276
# Density\n(P/Km2)                                                       0
# Land Area(Km2)                                                         0
# Latitude                                                               0
# Longitude                                                              0
# dtype: int64

# %%
Eligible.drop(["Financial flows to developing countries (US $)",
               "Renewables (% equivalent primary energy)"], axis = 1, inplace = True) # Too many missing values
Eligible.drop(["Latitude", "Longitude", "Land Area(Km2)", "Density\\n(P/Km2)"], axis = 1, inplace=True) # Irrelevant
Eligible.drop(['gdp_growth'], axis=1, inplace=True)
# Out:
# C:\Users\Nico\AppData\Local\Temp\ipykernel_8448\1985937368.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Eligible.drop(["Financial flows to developing countries (US $)",
# C:\Users\Nico\AppData\Local\Temp\ipykernel_8448\1985937368.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Eligible.drop(["Latitude", "Longitude", "Land Area(Km2)", "Density\\n(P/Km2)"], axis = 1, inplace=True) # Irrelevant
# C:\Users\Nico\AppData\Local\Temp\ipykernel_8448\1985937368.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Eligible.drop(['gdp_growth'], axis=1, inplace=True)

# %%
def fillBlankByEntityyMean(colName):
    meanByEntity = Eligible.groupby('Entity')[colName].transform('mean')
    Eligible[colName].fillna(meanByEntity, inplace = True)

# %%
fillBlankByEntityyMean('Electricity from fossil fuels (TWh)')
fillBlankByEntityyMean('Electricity from nuclear (TWh)')
fillBlankByEntityyMean('Electricity from renewables (TWh)')
fillBlankByEntityyMean('Low-carbon electricity (% electricity)')
fillBlankByEntityyMean('Value_co2_emissions_kt_by_country')
fillBlankByEntityyMean('Access to clean fuels for cooking')
fillBlankByEntityyMean('Renewable energy share in the total final energy consumption (%)')
fillBlankByEntityyMean('Energy intensity level of primary energy (MJ/$2017 PPP GDP)')

Eligible['Access to electricity (% of population)'].fillna(0, inplace = True)
Eligible['Renewable-electricity-generating-capacity-per-capita'].fillna(0, inplace = True)
# Out:
# C:\Users\Nico\AppData\Local\Temp\ipykernel_8448\2856198078.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Eligible[colName].fillna(meanByEntity, inplace = True)
# C:\Users\Nico\AppData\Local\Temp\ipykernel_8448\2856198078.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Eligible[colName].fillna(meanByEntity, inplace = True)
# C:\Users\Nico\AppData\Local\Temp\ipykernel_8448\2856198078.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Eligible[colName].fillna(meanByEntity, inplace = True)
# C:\Users\Nico\AppData\Local\Temp\ipykernel_8448\2856198078.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Eligible[colName].fillna(meanByEntity, inplace = True)
# C:\Users\Nico\AppData\Local\Temp\ipykernel_8448\2856198078.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Eligible[colName].fillna(meanByEntity, inplace = True)
# C:\Users\Nico\AppData\Local\Temp\ipykernel_8448\2856198078.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Eligible[colName].fillna(meanByEntity, inplace = True)
# C:\Users\Nico\AppData\Local\Temp\ipykernel_8448\2856198078.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Eligible[colName].fillna(meanByEntity, inplace = True)
# C:\Users\Nico\AppData\Local\Temp\ipykernel_8448\2856198078.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Eligible[colName].fillna(meanByEntity, inplace = True)
# C:\Users\Nico\AppData\Local\Temp\ipykernel_8448\2324541556.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Eligible['Access to electricity (% of population)'].fillna(0, inplace = True)
# C:\Users\Nico\AppData\Local\Temp\ipykernel_8448\2324541556.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Eligible['Renewable-electricity-generating-capacity-per-capita'].fillna(0, inplace = True)

# %%
Eligible.isnull().sum()
# Out:
# Entity                                                                0
# Year                                                                  0
# Access to electricity (% of population)                               0
# Access to clean fuels for cooking                                   168
# Renewable-electricity-generating-capacity-per-capita                  0
# Renewable energy share in the total final energy consumption (%)     21
# Electricity from fossil fuels (TWh)                                  21
# Electricity from nuclear (TWh)                                      126
# Electricity from renewables (TWh)                                    21
# Low-carbon electricity (% electricity)                               42
# Primary energy consumption per capita (kWh/person)                    0
# Energy intensity level of primary energy (MJ/$2017 PPP GDP)          21
# Value_co2_emissions_kt_by_country                                   252
# gdp_per_capita                                                      276
# dtype: int64

# %%
print(Eligible.shape)
dataset = Eligible.dropna()
print(dataset.shape)
dataset.isnull().sum()
# Out:
# (3612, 14)
# (3009, 14)
# Entity                                                              0
# Year                                                                0
# Access to electricity (% of population)                             0
# Access to clean fuels for cooking                                   0
# Renewable-electricity-generating-capacity-per-capita                0
# Renewable energy share in the total final energy consumption (%)    0
# Electricity from fossil fuels (TWh)                                 0
# Electricity from nuclear (TWh)                                      0
# Electricity from renewables (TWh)                                   0
# Low-carbon electricity (% electricity)                              0
# Primary energy consumption per capita (kWh/person)                  0
# Energy intensity level of primary energy (MJ/$2017 PPP GDP)         0
# Value_co2_emissions_kt_by_country                                   0
# gdp_per_capita                                                      0
# dtype: int64

# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn import metrics

# %%
from sklearn.preprocessing import FunctionTransformer

scaler = FunctionTransformer(np.log1p)

colName = [
    'Access to electricity (% of population)',
    'Access to clean fuels for cooking',
    'Renewable-electricity-generating-capacity-per-capita',
    'Renewable energy share in the total final energy consumption (%)',
    'Electricity from fossil fuels (TWh)', 
    'Electricity from nuclear (TWh)',
    'Electricity from renewables (TWh)',
    'Low-carbon electricity (% electricity)',
    'Primary energy consumption per capita (kWh/person)',
    'Energy intensity level of primary energy (MJ/$2017 PPP GDP)',
    'Value_co2_emissions_kt_by_country']

for i in colName:
    dataset[i] = scaler.fit_transform(dataset[i].values.reshape(-1, 1))
# Out:
# C:\Users\Nico\AppData\Local\Temp\ipykernel_8448\863374849.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset[i] = scaler.fit_transform(dataset[i].values.reshape(-1, 1))

# %%
dataset['gdp_per_capita_category'] = np.nan
medians = dataset.groupby('Year')['gdp_per_capita'].median()
medians
# Out:
# C:\Users\Nico\AppData\Local\Temp\ipykernel_8448\3939401048.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['gdp_per_capita_category'] = np.nan
# Year
# 2000    1861.898065
# 2001    1824.101683
# 2002    1845.669127
# 2003    2209.497245
# 2004    2610.185422
# 2005    3002.138604
# 2006    3362.968419
# 2007    3851.437869
# 2008    4307.580023
# 2009    4196.311627
# 2010    4607.145023
# 2011    5392.533420
# 2012    5682.046108
# 2013    5718.281645
# 2014    5778.746317
# 2015    5402.245114
# 2016    5094.635480
# 2017    5564.681427
# 2018    6089.544595
# 2019    6095.075200
# 2020    5001.072760
# Name: gdp_per_capita, dtype: float64

# %%
def categorize(row):
    year = row['Year']
    val = row['gdp_per_capita']
    med = medians.loc[year]
    if val <= med:
        return 0
    else:
        return 1

dataset['gdp_per_capita_category'] = dataset.apply(categorize, axis=1)
# Out:
# C:\Users\Nico\AppData\Local\Temp\ipykernel_8448\3831593846.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['gdp_per_capita_category'] = dataset.apply(categorize, axis=1)

# %%
dataset.drop(['gdp_per_capita'], axis=1, inplace=True) # Unused
dataset.drop(['Entity', 'Year'], axis = 1, inplace=True) # Irrelevant

dataset.head()
# Out:
# C:\Users\Nico\AppData\Local\Temp\ipykernel_8448\218864465.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset.drop(['gdp_per_capita'], axis=1, inplace=True) # Unused
# C:\Users\Nico\AppData\Local\Temp\ipykernel_8448\218864465.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset.drop(['Entity', 'Year'], axis = 1, inplace=True) # Irrelevant
#    Access to electricity (% of population)  Access to clean fuels for cooking  \
# 2                                 2.342686                           2.219203
# 3                                 2.756110                           2.351375
# 4                                 3.047611                           2.476538
# 5                                 3.273019                           2.580217
# 6                                 3.456906                           2.698000
#
#    Renewable-electricity-generating-capacity-per-capita  \
# 2                                           2.248129
# 3                                           2.207175
# 4                                           2.169054
# 5                                           2.141242
# 6                                           2.128232
#
#    Renewable energy share in the total final energy consumption (%)  \
# 2                                           3.659193
# 3                                           3.628599
# 4                                           3.811982
# 5                                           3.551914
# 6                                           3.493169
#
#    Electricity from fossil fuels (TWh)  Electricity from nuclear (TWh)  \
# 2                             0.122218                             0.0
# 3                             0.270027                             0.0
# 4                             0.285179                             0.0
# 5                             0.292670                             0.0
# 6                             0.182322                             0.0
#
#    Electricity from renewables (TWh)  Low-carbon electricity (% electricity)  \
# 2                           0.444686                                4.408662
# 3                           0.488580                                4.219821
# 4                           0.444686                                4.157653
# 5                           0.463734                                4.165748
# 6                           0.494696                                4.346276
#
#    Primary energy consumption per capita (kWh/person)  \
# 2                                           5.355936
# 3                                           5.442280
# 4                                           5.324137
# 5                                           5.533663
# 6                                           5.721691
#
#    Energy intensity level of primary energy (MJ/$2017 PPP GDP)  \
# 2                                           0.875469
# 3                                           0.875469
# 4                                           0.788457
# 5                                           0.879627
# 6                                           0.916291
#
#    Value_co2_emissions_kt_by_country  gdp_per_capita_category
# 2                           6.938284                        0
# 3                           7.107425                        0
# 4                           6.938284                        0
# 5                           7.346655                        0
# 6                           7.473637                        0

# %%
print(dataset.corr()['gdp_per_capita_category'])
# Out:
# Access to electricity (% of population)                             0.534290
# Access to clean fuels for cooking                                   0.656317
# Renewable-electricity-generating-capacity-per-capita               -0.276772
# Renewable energy share in the total final energy consumption (%)   -0.491966
# Electricity from fossil fuels (TWh)                                 0.403305
# Electricity from nuclear (TWh)                                      0.290205
# Electricity from renewables (TWh)                                   0.270134
# Low-carbon electricity (% electricity)                             -0.087119
# Primary energy consumption per capita (kWh/person)                  0.752527
# Energy intensity level of primary energy (MJ/$2017 PPP GDP)        -0.311200
# Value_co2_emissions_kt_by_country                                   0.400412
# gdp_per_capita_category                                             1.000000
# Name: gdp_per_capita_category, dtype: float64

# %%
x = dataset.drop(['gdp_per_capita_category'], axis = 1)
y = dataset['gdp_per_capita_category']

x_train, x_test, y_train, y_test = train_test_split(x, y, train_size = 0.7)

# %%
model = SVC(kernel='linear')
model.fit(x_train, y_train)
prediction = model.predict(x_test)

print(f"Accuracy = {metrics.accuracy_score(prediction, y_test)}")
# Out:
# Accuracy = 0.9302325581395349

# %%
category_amt = 2
precision = np.zeros(category_amt)

for i in range(category_amt):
    precision[i] = metrics.precision_score(y_test, prediction, average=None)[i]

plt.figure(figsize=[8,5])
plt.bar(np.arange(0,category_amt,1), precision)
plt.title(f"Precision for each label")
plt.ylabel("Percentage")
plt.xlabel("Label")
plt.plot()
# Out:
# []

# %%
confusionMatrix = metrics.confusion_matrix(y_test, prediction)

figure = metrics.ConfusionMatrixDisplay(confusionMatrix)
figure.plot()
