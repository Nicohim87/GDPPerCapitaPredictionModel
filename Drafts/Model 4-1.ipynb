# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

# %%
dataset = pd.read_csv("dataset_new.csv")
dataset.drop(["Unnamed: 0", "gdp_growth"], axis = 1, inplace=True)
dataset.head()
# Out:
#         Entity  Year  Access to electricity (% of population)  \
# 0  Afghanistan  2003                                14.738506
# 1  Afghanistan  2004                                20.064968
# 2  Afghanistan  2005                                25.390894
# 3  Afghanistan  2006                                30.718690
# 4  Afghanistan  2007                                36.051010
#
#    Access to clean fuels for cooking  \
# 0                               9.50
# 1                              10.90
# 2                              12.20
# 3                              13.85
# 4                              15.30
#
#    Renewable-electricity-generating-capacity-per-capita  \
# 0                                               8.09
# 1                                               7.75
# 2                                               7.51
# 3                                               7.40
# 4                                               7.25
#
#    Renewable energy share in the total final energy consumption (%)  \
# 0                                              36.66
# 1                                              44.24
# 2                                              33.88
# 3                                              31.89
# 4                                              28.78
#
#    Electricity from fossil fuels (TWh)  Electricity from nuclear (TWh)  \
# 0                                 0.31                             0.0
# 1                                 0.33                             0.0
# 2                                 0.34                             0.0
# 3                                 0.20                             0.0
# 4                                 0.20                             0.0
#
#    Electricity from renewables (TWh)  Low-carbon electricity (% electricity)  \
# 0                               0.63                               67.021280
# 1                               0.56                               62.921350
# 2                               0.59                               63.440857
# 3                               0.64                               76.190475
# 4                               0.75                               78.947370
#
#    Primary energy consumption per capita (kWh/person)  \
# 0                                          229.96822
# 1                                          204.23125
# 2                                          252.06912
# 3                                          304.42090
# 4                                          354.27990
#
#    Energy intensity level of primary energy (MJ/$2017 PPP GDP)  \
# 0                                               1.40
# 1                                               1.20
# 2                                               1.41
# 3                                               1.50
# 4                                               1.53
#
#    Value_co2_emissions_kt_by_country  gdp_per_capita
# 0                        1220.000029      190.683814
# 1                        1029.999971      211.382074
# 2                        1549.999952      242.031313
# 3                        1759.999990      263.733602
# 4                        1769.999981      359.693158

# %%
def conversion(colName, newColName):
    dataset[newColName] = np.nan
    median_col = dataset.groupby('Year')[colName].median()
    dataset[newColName] = dataset.apply(lambda row: row[colName] > median_col[row['Year']], axis=1)
    dataset.drop([colName], axis = 1, inplace = True)

colName = [
    'Access to electricity (% of population)',
    'Access to clean fuels for cooking',
    'Renewable-electricity-generating-capacity-per-capita',
    'Renewable energy share in the total final energy consumption (%)',
    'Electricity from fossil fuels (TWh)', 
    'Electricity from nuclear (TWh)',
    'Electricity from renewables (TWh)',
    'Low-carbon electricity (% electricity)',
    'Primary energy consumption per capita (kWh/person)',
    'Energy intensity level of primary energy (MJ/$2017 PPP GDP)',
    'Value_co2_emissions_kt_by_country', 
    'gdp_per_capita']
    
newColName = [
    'Access to electricity above avg',
    'Access to clean fuels for cooking above avg',
    'Renewable electricity generating capacity per capita above avg',
    'Renewable energy share in the total final energy consumption above avg',
    'Electricity from fossil fuels above avg', 
    'Electricity from nuclear above avg',
    'Electricity from renewables above avg',
    'Low-carbon electricity above avg',
    'Primary energy consumption per capita above avg',
    'Energy intensity level of primary energy above avg',
    'Value_co2_emissions_kt_by_country_above_avg', 
    'gdp_per_capita_above_avg']

# %%
for i in range(len(colName)):
    conversion(colName[i], newColName[i])

dataset.drop(['Entity', 'Year'], axis = 1, inplace=True)
dataset.head()
# Out:
#    Access to electricity above avg  \
# 0                            False
# 1                            False
# 2                            False
# 3                            False
# 4                            False
#
#    Access to clean fuels for cooking above avg  \
# 0                                        False
# 1                                        False
# 2                                        False
# 3                                        False
# 4                                        False
#
#    Renewable electricity generating capacity per capita above avg  \
# 0                                               True
# 1                                               True
# 2                                               True
# 3                                               True
# 4                                               True
#
#    Renewable energy share in the total final energy consumption above avg  \
# 0                                               True
# 1                                               True
# 2                                               True
# 3                                               True
# 4                                               True
#
#    Electricity from fossil fuels above avg  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                    False
#
#    Electricity from nuclear above avg  Electricity from renewables above avg  \
# 0                               False                                  False
# 1                               False                                  False
# 2                               False                                  False
# 3                               False                                  False
# 4                               False                                  False
#
#    Low-carbon electricity above avg  \
# 0                              True
# 1                              True
# 2                              True
# 3                              True
# 4                              True
#
#    Primary energy consumption per capita above avg  \
# 0                                            False
# 1                                            False
# 2                                            False
# 3                                            False
# 4                                            False
#
#    Energy intensity level of primary energy above avg  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Value_co2_emissions_kt_by_country_above_avg  gdp_per_capita_above_avg
# 0                                        False                     False
# 1                                        False                     False
# 2                                        False                     False
# 3                                        False                     False
# 4                                        False                     False

# %%
print(dataset.corr()['gdp_per_capita_above_avg'])
# Out:
# Access to electricity above avg                                           0.600113
# Access to clean fuels for cooking above avg                               0.705093
# Renewable electricity generating capacity per capita above avg           -0.283998
# Renewable energy share in the total final energy consumption above avg   -0.503860
# Electricity from fossil fuels above avg                                   0.347684
# Electricity from nuclear above avg                                        0.277481
# Electricity from renewables above avg                                     0.095253
# Low-carbon electricity above avg                                         -0.123197
# Primary energy consumption per capita above avg                           0.713588
# Energy intensity level of primary energy above avg                       -0.271768
# Value_co2_emissions_kt_by_country_above_avg                               0.362554
# gdp_per_capita_above_avg                                                  1.000000
# Name: gdp_per_capita_above_avg, dtype: float64

# %%
x = dataset.drop(['gdp_per_capita_above_avg'], axis = 1)
y = dataset['gdp_per_capita_above_avg']

x_train, x_test, y_train, y_test = train_test_split(x, y, train_size = 0.7)

# %%
model = LogisticRegression()
model.fit(x_train, y_train)
prediction = model.predict(x_test)

print(metrics.accuracy_score(prediction, y_test))
print(metrics.f1_score(prediction, y_test))
# Out:
# 0.8766430738119313
# 0.872651356993737

# %%
confusionMatrix = metrics.confusion_matrix(y_test, prediction)

figure = metrics.ConfusionMatrixDisplay(confusionMatrix)
figure.plot()
