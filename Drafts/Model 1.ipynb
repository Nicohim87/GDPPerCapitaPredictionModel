# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
dataset = pd.read_csv("dataset_new.csv")
dataset.drop(["Unnamed: 0"], axis = 1, inplace=True)
dataset
# Out:
#            Entity  Year  Access to electricity (% of population)  \
# 0     Afghanistan  2003                                14.738506
# 1     Afghanistan  2004                                20.064968
# 2     Afghanistan  2005                                25.390894
# 3     Afghanistan  2006                                30.718690
# 4     Afghanistan  2007                                36.051010
# ...           ...   ...                                      ...
# 3291     Zimbabwe  2016                                42.561730
# 3292     Zimbabwe  2017                                44.178635
# 3293     Zimbabwe  2018                                45.572647
# 3294     Zimbabwe  2019                                46.781475
# 3295     Zimbabwe  2020                                52.747670
#
#       Access to clean fuels for cooking  \
# 0                                  9.50
# 1                                 10.90
# 2                                 12.20
# 3                                 13.85
# 4                                 15.30
# ...                                 ...
# 3291                              29.80
# 3292                              29.80
# 3293                              29.90
# 3294                              30.10
# 3295                              30.40
#
#       Renewable-electricity-generating-capacity-per-capita  \
# 0                                                  8.09
# 1                                                  7.75
# 2                                                  7.51
# 3                                                  7.40
# 4                                                  7.25
# ...                                                 ...
# 3291                                              62.88
# 3292                                              62.33
# 3293                                              82.53
# 3294                                              81.40
# 3295                                              80.61
#
#       Renewable energy share in the total final energy consumption (%)  \
# 0                                                 36.66
# 1                                                 44.24
# 2                                                 33.88
# 3                                                 31.89
# 4                                                 28.78
# ...                                                 ...
# 3291                                              81.90
# 3292                                              82.46
# 3293                                              80.23
# 3294                                              81.50
# 3295                                              81.90
#
#       Electricity from fossil fuels (TWh)  Electricity from nuclear (TWh)  \
# 0                                    0.31                             0.0
# 1                                    0.33                             0.0
# 2                                    0.34                             0.0
# 3                                    0.20                             0.0
# 4                                    0.20                             0.0
# ...                                   ...                             ...
# 3291                                 3.50                             0.0
# 3292                                 3.05                             0.0
# 3293                                 3.73                             0.0
# 3294                                 3.66                             0.0
# 3295                                 3.40                             0.0
#
#       Electricity from renewables (TWh)  \
# 0                                  0.63
# 1                                  0.56
# 2                                  0.59
# 3                                  0.64
# 4                                  0.75
# ...                                 ...
# 3291                               3.32
# 3292                               4.30
# 3293                               5.46
# 3294                               4.58
# 3295                               4.19
#
#       Low-carbon electricity (% electricity)  \
# 0                                  67.021280
# 1                                  62.921350
# 2                                  63.440857
# 3                                  76.190475
# 4                                  78.947370
# ...                                      ...
# 3291                               48.680350
# 3292                               58.503407
# 3293                               59.412407
# 3294                               55.582527
# 3295                               55.204216
#
#       Primary energy consumption per capita (kWh/person)  \
# 0                                             229.96822
# 1                                             204.23125
# 2                                             252.06912
# 3                                             304.42090
# 4                                             354.27990
# ...                                                 ...
# 3291                                         3227.68020
# 3292                                         3068.01150
# 3293                                         3441.98580
# 3294                                         3003.65530
# 3295                                         2680.13180
#
#       Energy intensity level of primary energy (MJ/$2017 PPP GDP)  \
# 0                                                  1.40
# 1                                                  1.20
# 2                                                  1.41
# 3                                                  1.50
# 4                                                  1.53
# ...                                                 ...
# 3291                                              10.00
# 3292                                               9.51
# 3293                                               9.83
# 3294                                              10.47
# 3295                                              10.00
#
#       Value_co2_emissions_kt_by_country  gdp_growth  gdp_per_capita
# 0                           1220.000029    8.832278      190.683814
# 1                           1029.999971    1.414118      211.382074
# 2                           1549.999952   11.229715      242.031313
# 3                           1759.999990    5.357403      263.733602
# 4                           1769.999981   13.826320      359.693158
# ...                                 ...         ...             ...
# 3291                       11020.000460    0.755869     1464.588957
# 3292                       10340.000150    4.709492     1235.189032
# 3293                       12380.000110    4.824211     1254.642265
# 3294                       11760.000230   -6.144236     1316.740657
# 3295                      161317.103611   -6.248748     1214.509820
#
# [3296 rows x 15 columns]

# %%
dataset.drop(['Entity', 'Year'], axis = 1, inplace=True)
dataset.head()
# Out:
#    Access to electricity (% of population)  Access to clean fuels for cooking  \
# 0                                14.738506                               9.50
# 1                                20.064968                              10.90
# 2                                25.390894                              12.20
# 3                                30.718690                              13.85
# 4                                36.051010                              15.30
#
#    Renewable-electricity-generating-capacity-per-capita  \
# 0                                               8.09
# 1                                               7.75
# 2                                               7.51
# 3                                               7.40
# 4                                               7.25
#
#    Renewable energy share in the total final energy consumption (%)  \
# 0                                              36.66
# 1                                              44.24
# 2                                              33.88
# 3                                              31.89
# 4                                              28.78
#
#    Electricity from fossil fuels (TWh)  Electricity from nuclear (TWh)  \
# 0                                 0.31                             0.0
# 1                                 0.33                             0.0
# 2                                 0.34                             0.0
# 3                                 0.20                             0.0
# 4                                 0.20                             0.0
#
#    Electricity from renewables (TWh)  Low-carbon electricity (% electricity)  \
# 0                               0.63                               67.021280
# 1                               0.56                               62.921350
# 2                               0.59                               63.440857
# 3                               0.64                               76.190475
# 4                               0.75                               78.947370
#
#    Primary energy consumption per capita (kWh/person)  \
# 0                                          229.96822
# 1                                          204.23125
# 2                                          252.06912
# 3                                          304.42090
# 4                                          354.27990
#
#    Energy intensity level of primary energy (MJ/$2017 PPP GDP)  \
# 0                                               1.40
# 1                                               1.20
# 2                                               1.41
# 3                                               1.50
# 4                                               1.53
#
#    Value_co2_emissions_kt_by_country  gdp_growth  gdp_per_capita
# 0                        1220.000029    8.832278      190.683814
# 1                        1029.999971    1.414118      211.382074
# 2                        1549.999952   11.229715      242.031313
# 3                        1759.999990    5.357403      263.733602
# 4                        1769.999981   13.826320      359.693158

# %%
x = dataset.drop(['gdp_growth'], axis = 1)
y = dataset['gdp_growth']

x_train, x_test, y_train, y_test = train_test_split(x, y, train_size = 0.7)

# %%
model = LogisticRegression()
model.fit(x_train, y_train)
prediction = model.predict(x_test)

print(metrics.accuracy_score(prediction, y_test))
print(metrics.f1_score(prediction, y_test))

# %%
confusionMatrix = metrics.confusion_matrix(y_test, prediction)

figure = metrics.ConfusionMatrixDisplay(confusionMatrix)
figure.plot()
