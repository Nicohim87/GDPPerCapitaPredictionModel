# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
dataset = pd.read_csv("dataset_new.csv")
dataset.drop(["Unnamed: 0", "gdp_growth"], axis = 1, inplace=True)
dataset.head()
# Out:
#         Entity  Year  Access to electricity (% of population)  \
# 0  Afghanistan  2003                                14.738506
# 1  Afghanistan  2004                                20.064968
# 2  Afghanistan  2005                                25.390894
# 3  Afghanistan  2006                                30.718690
# 4  Afghanistan  2007                                36.051010
#
#    Access to clean fuels for cooking  \
# 0                               9.50
# 1                              10.90
# 2                              12.20
# 3                              13.85
# 4                              15.30
#
#    Renewable-electricity-generating-capacity-per-capita  \
# 0                                               8.09
# 1                                               7.75
# 2                                               7.51
# 3                                               7.40
# 4                                               7.25
#
# ...

# %%
dataset.drop(['Entity', 'Year'], axis = 1, inplace=True)
print(dataset.corr()['gdp_per_capita'])
# Out:
# Access to electricity (% of population)                             0.418252
# Access to clean fuels for cooking                                   0.497293
# Renewable-electricity-generating-capacity-per-capita               -0.139702
# Renewable energy share in the total final energy consumption (%)   -0.356292
# Electricity from fossil fuels (TWh)                                 0.108661
# Electricity from nuclear (TWh)                                      0.232444
# Electricity from renewables (TWh)                                   0.140837
# Low-carbon electricity (% electricity)                              0.008033
# Primary energy consumption per capita (kWh/person)                  0.666997
# Energy intensity level of primary energy (MJ/$2017 PPP GDP)        -0.180257
# Value_co2_emissions_kt_by_country                                   0.093823
# gdp_per_capita                                                      1.000000
# Name: gdp_per_capita, dtype: float64

# %%
x = dataset.drop(['gdp_per_capita'], axis = 1)
y = dataset['gdp_per_capita']

x_train, x_test, y_train, y_test = train_test_split(x, y, train_size = 0.7)

# %%
model = LinearRegression()
model.fit(x_train, y_train)
prediction = model.predict(x_test)

# %%
mae = mean_absolute_error(y_test, prediction)
mse = mean_squared_error(y_test, prediction)

print("Mean Absolute Error:", mae)
print("Mean Squared Error:", mse)
# Out:
# Mean Absolute Error: 7652.201282256667
# Mean Squared Error: 145983944.80209532
